# %%
import pandas as pd
import ast

# %%
final_results = pd.DataFrame(columns = ["Name", "Description", "Category", "URL", "Small_Image", "Large_Image", "Tags"])

categories = ["Programmas", "Series", "Documentaires", "Films"]

# %%
"""This code process a set of CSV files, each corresponding to a category of items of the NPO platform, 
and concatenates them into a single dataframe called final_results."""

for category in categories:
    df = pd.read_csv("{}_complete.csv".format(category))
    df = df.drop("Unnamed: 0", axis=1)

    # Drop columns that do not have description
    df = df[~df['Description'].isnull()]

    # Convert the tags column into lists
    df["Tags"] = df["Tags"].apply(lambda x : ast.literal_eval(x))

    # Drop tags that contain the number of seasons
    df["Tags"] = df["Tags"].apply(lambda x: [tag for tag in x if not 'seizoen' in tag])

    # Drop columns that do not have any tag
    if category == "Programmas":
        df = df[df["Tags"].str.len() > 1]
    else:
        df = df[df["Tags"].str.len() > 0]

    # Add results of this category to the final dataframe
    final_results = pd.concat([df, final_results.loc[:]]).reset_index(drop=True)

# %%
display(final_results)
# Out:
#                                        Name  \
# 0                          Wallace & Gromit
# 1                                     Sissi
# 2                 Sissi, die junge Kaiserin
# 3                   Charlie & Lola specials
# 4     Sissi, Schicksalsjahre einer Kaiserin
# ...                                     ...
# 1688                        Fight or Flight
# 1689                     Flikken Maastricht
# 1690                                   2Doc
# 1691                           NOS Journaal
# 1692                          Down the Road
#
#                                             Description    Category  \
# 0     Engelse animatiefilm. Wallace en Gromit runnen...       Films
# 1     Op 16-jarige leeftijd ontmoet Sissi de keizer ...       Films
# 2     Sissi heeft het onbezorgde leventje moeten inr...       Films
# 3       Specials over de avonturen van Charlie en Lola.       Films
# 4     Franz Joseph en Sissi zijn noodgedwongen regel...       Films
# ...                                                 ...         ...
# 1688  Sahil Amar Aïssa portretteert twee mensen die ...  Programmas
# 1689  Moord en doodslag, chantagepraktijken, verdwij...  Programmas
# 1690  Alle documentaires die onder de noemer 2Doc: u...  Programmas
# 1691  Het laatste nieuws, gebeurtenissen van nationa...  Programmas
# 1692  Dieter Coppens gaat op avontuur met medebegele...  Programmas
#
#                                                     URL  \
# 0     https://www.npostart.nl/wallace-gromit/21-12-2...
# 1     https://www.npostart.nl/sissi/25-12-2008/POW_0...
# 2     https://www.npostart.nl/sissi-die-junge-kaiser...
# 3     https://www.npostart.nl/charlie-lola-specials/...
# 4     https://www.npostart.nl/sissi-schicksalsjahre-...
# ...                                                 ...
# 1688  https://www.npostart.nl/fight-or-flight/BV_101...
# 1689  https://www.npostart.nl/flikken-maastricht/AT_...
# 1690    https://www.npostart.nl/2doc/POMS_S_VPRO_472240
# 1691   https://www.npostart.nl/nos-journaal/NOSJournaal
# 1692  https://www.npostart.nl/down-the-road/VPWON_12...
#
#                                             Small_Image  \
# 0     https://weserv.moviemeter.nl/?url=https://www....
# 1     https://weserv.moviemeter.nl/?url=https://www....
# 2     https://weserv.moviemeter.nl/?url=https://www....
# 3     https://weserv.moviemeter.nl/?url=https://www....
# 4     https://weserv.moviemeter.nl/?url=https://www....
# ...                                                 ...
# 1688     https://images.npo.nl/tile/320x180/1903091.jpg
# 1689  https://images.npo.nl/tile/320x180/Flikken_Maa...
# 1690  https://images.npo.nl/tile/320x180/V3_nacht_cd...
# 1691  https://images.npo.nl/tile/320x180/nos_journaa...
# 1692  https://images.npo.nl/tile/320x180/down_the_ro...
#
#                                             Large_Image                  Tags
# 0     https://weserv.moviemeter.nl/?url=https://www....   [Animatie, Komedie]
# 1     https://weserv.moviemeter.nl/?url=https://www....    [Drama, Romantiek]
# 2     https://weserv.moviemeter.nl/?url=https://www....   [Drama, Historisch]
# 3     https://weserv.moviemeter.nl/?url=https://www....      [Misdaad, Drama]
# 4     https://weserv.moviemeter.nl/?url=https://www....   [Drama, Historisch]
# ...                                                 ...                   ...
# 1688     https://images.npo.nl/tile/320x180/1903091.jpg     [Actie, Thriller]
# 1689  https://images.npo.nl/tile/320x180/Flikken_Maa...      [Misdaad, Drama]
# 1690  https://images.npo.nl/tile/320x180/V3_nacht_cd...  [Komedie, Romantiek]
# 1691  https://images.npo.nl/tile/320x180/nos_journaa...    [Drama, Romantiek]
# 1692  https://images.npo.nl/tile/320x180/down_the_ro...    [Horror, Thriller]
#
# [1693 rows x 7 columns]

# %%
# Count the number of items per category
final_results.groupby("Category")["Category"].count()
# Out:
# Category
# Documentaires    193
# Films            308
# Programmas       930
# Series           262
# Name: Category, dtype: int64

# %%
final_results.to_csv("Final_NPO_Data.csv", index=False)
